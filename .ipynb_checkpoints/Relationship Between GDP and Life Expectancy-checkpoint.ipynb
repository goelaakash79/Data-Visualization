# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv('countries.csv')

# %%
data_2007 = data[data.year == 2007]

# %%
gdp_in_billions = (data_2007.gdpPerCapita * data_2007.population) / 10**9

# %%
plt.scatter(np.log10(gdp_in_billions), data_2007.lifeExpectancy, 5)
plt.show()

# %%
plt.scatter(np.log10(data_2007.gdpPerCapita), data_2007.lifeExpectancy, 5)
plt.show()

# %%
print('Correlation between log10 of GDP amd life expectancy:')
print(np.log10(gdp_in_billions).corr(data_2007.lifeExpectancy))
print('Correlation between log10 of GDP per capita amd life expectancy:')
print(np.log10(data_2007.gdpPerCapita).corr(data_2007.lifeExpectancy))
# Out:
# Correlation between log10 of GDP amd life expectancy:
# 0.600040537644758
# Correlation between log10 of GDP per capita amd life expectancy:
# 0.8089802514849209
